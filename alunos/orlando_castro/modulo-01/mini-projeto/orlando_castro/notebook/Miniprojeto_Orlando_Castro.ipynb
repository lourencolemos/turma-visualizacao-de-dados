# %% [markdown]
# # 📊 Mini-Projeto Avaliativo
#
# ### Aluno: Orlando Vieira de Castro Junior
# **Data:** 26/05/2026
#
# ---
#
# ### ETAPAS DA TAREFA
#
# #### PASSO 1 - Carregar a base Varejo.csv com pandas e mostrar: número de registros, colunas e tipos de dados.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# URL da planilha que usamos nesta aula
URL = (
    "https://raw.githubusercontent.com/"
    "cfneves/turma-visualizacao-de-dados/"
    "master/alunos/orlando_castro/modulo_1/mini-projeto/orlando_castro/dataset/Varejo.csv"
)

# Lê o arquivo CSV diretamente da internet
df = pd.read_csv(URL)

# Mostra quantas linhas e colunas temos e os tipos de cada coluna
print(f"Dataset: {df.shape[0]} linhas x {df.shape[1]} colunas")
print(df.dtypes)

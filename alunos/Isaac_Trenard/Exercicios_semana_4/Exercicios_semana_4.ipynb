# %% [markdown]
# # ── Resolva o exercício aqui ──────────────────────────────────────────────
#
#
#
# # Passo 2: diagnóstico
#
#
# # Passo 3: converter datas e criar colunas derivadas
#
#
# # Passo 4: groupby — maior e menor média de tempo de casa
#
#
# # Passo 5: exportar para Excel
#
#
# # Passo 6: cole o output do git log aqui como comentário
# # git log:

# %%
import pandas as pd 
import re            
from datetime import datetime  
print('✓ pandas versão:', pd.__version__)
print('✓ Bibliotecas importadas com sucesso!')

# Passo 1: carregue o CSV
local = r'CC:\Users\miran\OneDrive\Desktop\turma-visualizacao-de-dados\alunos\Isaac_Trenard\semana_04_ANOTAÇÕES\bases\base_rbase_rh_dia01h.csv'
# Out:
# ✓ pandas versão: 3.0.1
# ✓ Bibliotecas importadas com sucesso!

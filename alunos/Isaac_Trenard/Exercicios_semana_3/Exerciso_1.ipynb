# %% [markdown]
# Exercicios praticos da semana 3 para realizar
#
# ### 1. Estrutura de lista
# Instrução: Crie uma lista chamada cidades com 4 nomes de cidades que você conhece. Depois, exiba a lista inteira no terminal.
#
# ### 2. Descobrir o índice de uma lista
# Instrução: Dada a lista animais = ["cachorro", "gato", "papagaio", "coelho", "hamster"], faça o programa descobrir e exibir em qual posição está o animal "coelho".
#
# ### 3. Adicionar ou remover
# Instrução: Crie uma lista vazia chamada compras. Adicione 3 itens nela usando append(). Depois, remova o último item usando pop(). Exiba a lista após cada etapa.
#
# ### 4. Usar TRY e EXCEPT
# Instrução: Crie uma lista com 3 números de sua escolha. Peça para o usuário digitar um índice. Tente mostrar o elemento desse índice. Se o índice não existir, capture o erro e exiba "Índice inválido!".
#
# ### 5. Métodos para obter informações da lista
# Instrução: Dada a lista notas = [8, 7, 9, 6, 8, 7, 10, 8], use os métodos/funções corretos para exibir:
#
# Quantos alunos têm nota (tamanho da lista)
#
# A maior nota
#
# A menor nota
#
# Quantas vezes a nota 8 aparece
#
# ### 6. Juntar listas numa lista
# Instrução: Crie duas listas: lista_a = [1, 2, 3] e lista_b = [4, 5, 6]. Una as duas em uma nova lista chamada lista_unida e exiba o resultado.
#
# ### 7. Ordenar lista
# Instrução: Dada a lista numeros = [15, 3, 8, 1, 20, 7], ordene em ordem crescente e exiba. Depois, ordene em ordem decrescente e exiba.
#
# ### 8. Usar método JOIN
# Instrução: Dada a lista palavras = ["hoje", "é", "um", "bom", "dia"], junte todas as palavras em uma única frase, separadas por espaço, e exiba.
#
# ### 🎯 Bônus (desafio final):
# Instrução: Crie um programa que:
#
# Peça para o usuário digitar 5 nomes e guarde em uma lista
#
# Mostre a lista completa
#
# Mostre o terceiro nome digitado (índice 2)
#
# Peça um nome para remover e remova da lista
#
# Mostre a lista em ordem alfabética
#
# Mostre a lista como uma frase usando join

# %%
print('hello mundo!')
# Out:
# hello mundo!
